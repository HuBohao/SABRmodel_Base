# %% [markdown]
# ## Always vectorize computation
# ## Don't use loop

# %%
import numpy as np
import timeit
from option_models import normal
from option_models import bsm

# %%
### only run this when you changed the class definition
import imp
imp.reload(normal)
imp.reload(bsm)

# %%
n_vec = 10000
strike = np.random.rand(n_vec)*200
spot = 100
vol = np.random.rand(n_vec)*10

# %%
start_time = timeit.default_timer()
price_vec = normal.price(strike, spot, vol, texp=1)
elapsed = timeit.default_timer() - start_time
print(elapsed)
# Out:
# 0.0045566131306222874

# %%
price_loop = np.zeros(strike.size)
start_time = timeit.default_timer()
for ind in range(strike.size):
    price_loop[ind] = normal.price(strike[ind], spot, vol[ind], texp=1)

elapsed = timeit.default_timer() - start_time
print(elapsed)
# Out:
# 2.9211417145405747

# %%
price_vec - price_loop
# Out:
# array([ 0.,  0.,  0., ...,  0.,  0.,  0.])
